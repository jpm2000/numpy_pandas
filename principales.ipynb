# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('/Users/juanmanrique/Documents/numpy_pandas/bestsellers with categories.csv', header=0, sep=',')

# %%
# Primer función para visualizar los datos
books.head(10)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
# 9                          A Man Called Ove: A Novel
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# ...

# %%
# Recomienda iniciar el analisis a los data frames con este codigo
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
# Me muestra la información y metricas estadisticas 
books.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
books.tail(10)
# Out:
#                                                   Name         Author  \
# 540                                             Wonder  R. J. Palacio
# 541                                             Wonder  R. J. Palacio
# 542                                             Wonder  R. J. Palacio
# 543                                             Wonder  R. J. Palacio
# 544                                             Wonder  R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)    Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 540          4.8    21625      9  2013      Fiction
# 541          4.8    21625      9  2014      Fiction
# ...

# %%
# Cuanta memoria estoy usando con el data frame, se usa para IA
books.memory_usage(deep=True)
# Out:
# Index            132
# Name           55233
# Author         34622
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          32040
# dtype: int64

# %%
# Me cuenta cuantos valores tengo por cada autor
books['Author'].value_counts()
# Out:
# Author
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: count, Length: 248, dtype: int64

# %%
books['Reviews'].value_counts()
# Out:
# Reviews
# 8580     10
# 5069      9
# 21834     8
# 19546     7
# 19576     6
#          ..
# 5272      1
# 3776      1
# 1930      1
# 13471     1
# 5680      1
# Name: count, Length: 346, dtype: int64

# %%
# Para limpiar el data set
'''
Primero voy a copiar la info
'''
books.iloc[0]
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                              JJ Smith
# User Rating                              4.7
# Reviews                                17350
# Price                                      8
# Year                                    2016
# Genre                            Non Fiction
# Name: 0, dtype: object

# %%
type(books)
# Out:
# pandas.core.frame.DataFrame

# %%
books = books.append(books.iloc[0]) @
# Out:
#   Cell In[13], line 1
#     books = books.append(books.iloc[0]) @
#                                          ^
# SyntaxError: invalid syntax

# %%
print(books)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
print(books.iloc[0])
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                              JJ Smith
# User Rating                              4.7
# Reviews                                17350
# Price                                      8
# Year                                    2016
# Genre                            Non Fiction
# Name: 0, dtype: object

# %%
new_books = books.append(books.iloc[1])
print(new_books)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ny/nr6bx0md18z69n341sp017h40000gn/T/ipykernel_97177/3853916136.py in ?()
# ----> 1 new_books = books.append(books.iloc[1])
#       2 print(new_books)
#
# ~/anaconda3/envs/py/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
print(books)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Eliminar duplicados 
books.drop_duplicates()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# puedo eliminar todos menos el ultimo
books.drop_duplicates(keep='last')
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Me organiza el data frame por años, con ascending=False lo hace de mayor a menor
books.sort_values('Year', ascending=False)
# Out:
#                                                   Name                 Author  \
# 549  You Are a Badass: How to Stop Doubting Your Gr...            Jen Sincero
# 294  School Zone - Big Preschool Workbook - Ages 4 ...            School Zone
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
# 263    P is for Potty! (Sesame Street) (Lift-the-Flap)        Naomi Kleinberg
# 130  Girl, Wash Your Face: Stop Believing the Lies ...          Rachel Hollis
# ..                                                 ...                    ...
# 418  The Last Olympian (Percy Jackson and the Olymp...           Rick Riordan
# 38           Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 92   Eat This, Not That! Thousands of Simple Food S...        David Zinczenko
# 139  Good to Great: Why Some Companies Make the Lea...            Jim Collins
# 299                                  Sookie Stackhouse       Charlaine Harris
#
# ...

# %%
books.sort_values('Year', ascending=True)
# Out:
#                                                   Name            Author  \
# 177                                      I, Alex Cross   James Patterson
# 131  Glenn Beck's Common Sense: The Case Against an...        Glenn Beck
# 417                                   The Last Lecture      Randy Pausch
# 241                       New Moon (The Twilight Saga)   Stephenie Meyer
# 72       Diary of a Wimpy Kid: The Last Straw (Book 3)       Jeff Kinney
# ..                                                 ...               ...
# 150                                               Guts  Raina Telgemeier
# 466  The Subtle Art of Not Giving a F*ck: A Counter...       Mark Manson
# 462                                 The Silent Patient  Alex Michaelides
# 130  Girl, Wash Your Face: Stop Believing the Lies ...     Rachel Hollis
# 549  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
books.memory_usage(deep=True)
# Out:
# Index            132
# Name           56763
# Author         34756
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          32040
# dtype: int64

# %%
books['Author'].value_counts()
# Out:
# Author
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: count, Length: 248, dtype: int64

# %%
books.iloc[0]
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                              JJ Smith
# User Rating                              4.7
# Reviews                                17350
# Price                                      8
# Year                                    2016
# Genre                            Non Fiction
# Name: 0, dtype: object

# %%
books.append(books.iloc(0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ny/nr6bx0md18z69n341sp017h40000gn/T/ipykernel_97177/3010230731.py in ?()
# ----> 1 books.append(books.iloc(0))
#
# ~/anaconda3/envs/py/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
books.drop_duplicates()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
new = {
    'Name': 'Gimnasio Moderno',
    'Author': 'JPM',
    'User Rating': 5.0,
    'Reviews': 2000,
    'Price': 15,
    'Year': 2018,
    'Genre': 'Fiction'
}
new
# Out:
# {'Name': 'Gimnasio Moderno',
#  'Author': 'JPM',
#  'User Rating': 5.0,
#  'Reviews': 2000,
#  'Price': 15,
#  'Year': 2018,
#  'Genre': 'Fiction'}

# %%
# lo raro es que como tal este data frame no me deja agregar nuevos valores con append
books.append(new)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ny/nr6bx0md18z69n341sp017h40000gn/T/ipykernel_97177/4280873596.py in ?()
#       1 # lo raro es que como tal este data frame no me deja agregar nuevos valores con append
# ----> 2 books.append(new)
#
# ~/anaconda3/envs/py/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
salaries = pd.read_csv('/Users/juanmanrique/Documents/numpy_pandas/financial_sample copy.csv', header=0, sep=",")
salaries
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold Manufacturing Price Sale Price  Gross Sales    Discounts  \
# ...

# %%
salaries.iloc[0]
# Out:
# Segment                Government
# Country                    Canada
# Product                 Carretera
# Discount Band                 NaN
# Units Sold                   1618
# Manufacturing Price          $ 3
# Sale Price                  $ 20
# Gross Sales             $ 32,370
# Discounts                       0
#  Sales                  $ 32,370
# COGS                    $ 16,185
# Profit                  $ 16,185
# Date                     1/1/2014
# Month Number                    1
# Month Name                January
# Year                         2014
# Name: 0, dtype: object

# %%
salaries = salaries.append(salaries.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ny/nr6bx0md18z69n341sp017h40000gn/T/ipykernel_97177/4078914181.py in ?()
# ----> 1 salaries = salaries.append(salaries.iloc[0])
#
# ~/anaconda3/envs/py/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
books.sort_values('Year', ascending=True)
# Out:
#                                                   Name            Author  \
# 177                                      I, Alex Cross   James Patterson
# 131  Glenn Beck's Common Sense: The Case Against an...        Glenn Beck
# 417                                   The Last Lecture      Randy Pausch
# 241                       New Moon (The Twilight Saga)   Stephenie Meyer
# 72       Diary of a Wimpy Kid: The Last Straw (Book 3)       Jeff Kinney
# ..                                                 ...               ...
# 150                                               Guts  Raina Telgemeier
# 466  The Subtle Art of Not Giving a F*ck: A Counter...       Mark Manson
# 462                                 The Silent Patient  Alex Michaelides
# 130  Girl, Wash Your Face: Stop Believing the Lies ...     Rachel Hollis
# 549  You Are a Badass: How to Stop Doubting Your Gr...       Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
books.sort_index(ascending=False)
# Out:
#                                                   Name  \
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# ..                                                 ...
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 3                               1984 (Signet Classics)
# 2              12 Rules for Life: An Antidote to Chaos
# 1                                    11/22/63: A Novel
# 0                        10-Day Green Smoothie Cleanse
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# ...
