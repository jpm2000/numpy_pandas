# %%
import pandas as pd

# %%
books = pd.read_csv('/Users/juanmanrique/Documents/numpy_pandas/bestsellers with categories.csv', header=0, sep=",")

# %%
books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Cual es el conteo por genero
'''
Cabe resaltar que cuando se realiza la agrupación el común se vuelve el indice
'''
books.groupby('Genre').count()
# Out:
#              Name  Author  User Rating  Reviews  Price  Year
# Genre
# Fiction       240     240          240      240    240   240
# Non Fiction   310     310          310      310    310   310

# %%
books.groupby('Author').max()
# Out:
#                                                                          Name  \
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                                    Steve Jobs
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# Zhi Gang Sha                Soul Healing Miracles: Ancient and New Sacred ...
#
# ...

# %%
books.groupby('Author').count()
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %%
books.groupby('Author').max()
# Out:
#                                                                          Name  \
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                                    Steve Jobs
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# Zhi Gang Sha                Soul Healing Miracles: Ancient and New Sacred ...
#
# ...

# %%
books.groupby('Author').min()
# Out:
#                                                                          Name  \
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                             Leonardo da Vinci
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# Zhi Gang Sha                Divine Soul Mind Body Healing and Transmission...
#
# ...

# %%
books.groupby('Author').median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/py/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~/anaconda3/envs/py/lib/python3.12/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/anaconda3/envs/py/lib/python3.12/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
# ...

# %%
books.groupby('Author').sum()
# Out:
#                                                                          Name  \
# Author
# Abraham Verghese                           Cutting for StoneCutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                         Leonardo da VinciSteve JobsSteve Jobs
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young            The Shack: Where Tragedy Confronts EternityThe...
# Wizards RPG Team            Player's Handbook (Dungeons & Dragons)Player's...
# Zhi Gang Sha                Divine Soul Mind Body Healing and Transmission...
#
# ...

# %%
books.groupby('Author').sum().loc['William Davis']
# Out:
# Name           Wheat Belly: Lose the Wheat, Lose the Weight, ...
# User Rating                                                  8.8
# Reviews                                                    14994
# Price                                                         12
# Year                                                        4025
# Genre                                     Non FictionNon Fiction
# Name: William Davis, dtype: object

# %%
# Como el indice se modifica cuando agrupo los valores, puedo restablecerlo con reset index
books.groupby('Author').sum().reset_index()
# Out:
#                          Author  \
# 0              Abraham Verghese
# 1                Adam Gasiewski
# 2                 Adam Mansbach
# 3                     Adir Levy
# 4    Admiral William H. McRaven
# ..                          ...
# 243             Walter Isaacson
# 244               William Davis
# 245            William P. Young
# 246            Wizards RPG Team
# 247                Zhi Gang Sha
#
#                                                   Name  User Rating  Reviews  \
# 0                   Cutting for StoneCutting for Stone          9.2     9732
# 1    Milk and Vine: Inspirational Quotes From Class...          4.4     3113
# 2                                 Go the F**k to Sleep          4.8     9568
# 3    What Should Danny Do? (The Power to Choose Ser...          4.8     8170
# 4    Make Your Bed: Little Things That Can Change Y...          4.7    10199
# ..                                                 ...          ...      ...
# ...

# %%
# Funciones de agregación. Quiero saber cual es el minimo y el maximo por cada uno.
books.groupby('Author').agg(['min', 'max'])
# Out:
#                                                                          Name  \
#                                                                           min
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                             Leonardo da Vinci
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# ...

# %%
books.groupby('Author').agg(['min', 'max']).reset_index()
# Out:
#                          Author  \
#
# 0              Abraham Verghese
# 1                Adam Gasiewski
# 2                 Adam Mansbach
# 3                     Adir Levy
# 4    Admiral William H. McRaven
# ..                          ...
# 243             Walter Isaacson
# 244               William Davis
# 245            William P. Young
# 246            Wizards RPG Team
# 247                Zhi Gang Sha
#
#                                                   Name  \
#                                                    min
# 0                                    Cutting for Stone
# 1    Milk and Vine: Inspirational Quotes From Class...
# 2                                 Go the F**k to Sleep
# 3    What Should Danny Do? (The Power to Choose Ser...
# 4    Make Your Bed: Little Things That Can Change Y...
# ..                                                 ...
# 243                                  Leonardo da Vinci
# 244  Wheat Belly: Lose the Wheat, Lose the Weight, ...
# ...

# %%
books.groupby('Author').agg({'Reviews': ['min', 'max'], 'User Rating': ['sum', 'count']})
# Out:
#                            Reviews        User Rating
#                                min    max         sum count
# Author
# Abraham Verghese              4866   4866         9.2     2
# Adam Gasiewski                3113   3113         4.4     1
# Adam Mansbach                 9568   9568         4.8     1
# Adir Levy                     8170   8170         4.8     1
# Admiral William H. McRaven   10199  10199         4.7     1
# ...                            ...    ...         ...   ...
# Walter Isaacson               3014   7827        13.7     3
# William Davis                 7497   7497         8.8     2
# William P. Young             19720  19720         9.2     2
# Wizards RPG Team             16990  16990        14.4     3
# Zhi Gang Sha                    37    220         9.2     2
#
# [248 rows x 4 columns]

# %%
# Puedo hacer una llave compuesta para la agrupación, multiples combinaciones con la llave de agrupación
books.groupby(['Author', 'Year', 'Genre']).count()
# Out:
#                                    Name  User Rating  Reviews  Price
# Author           Year Genre
# Abraham Verghese 2010 Fiction         1            1        1      1
#                  2011 Fiction         1            1        1      1
# Adam Gasiewski   2017 Non Fiction     1            1        1      1
# Adam Mansbach    2011 Fiction         1            1        1      1
# Adir Levy        2019 Fiction         1            1        1      1
# ...                                 ...          ...      ...    ...
# Wizards RPG Team 2017 Fiction         1            1        1      1
#                  2018 Fiction         1            1        1      1
#                  2019 Fiction         1            1        1      1
# Zhi Gang Sha     2009 Non Fiction     1            1        1      1
#                  2013 Non Fiction     1            1        1      1
#
# [493 rows x 4 columns]

# %%
books.groupby(level=0)

# %%
books.groupby(by=["b"]).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/juanmanrique/Documents/numpy_pandas/groupby.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/Users/juanmanrique/Documents/numpy_pandas/groupby.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> books.groupby(by=["b"]).sum()
#
# File ~/anaconda3/envs/py/lib/python3.12/site-packages/pandas/core/frame.py:8872, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8869 if level is None and by is None:
#    8870     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8872 return DataFrameGroupBy(
#    8873     obj=self,
#    8874     keys=by,
#    8875     axis=axis,
#    8876     level=level,
#    8877     as_index=as_index,
#    8878     sort=sort,
#    8879     group_keys=group_keys,
#    8880     observed=observed,
#    8881     dropna=dropna,
#    8882 )
#
# ...
